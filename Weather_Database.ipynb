# %%
# Import the Dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
# Import library requests.
import requests
import datetime
import time

#Import API key.
from config import weather_api_key

# %%
# Create a new set of 2,000 random latitudes and longitudes
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# %%
# Create a list for latitudes and longitudes
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)
print (coordinates)
# Out:
# [(86.97161918213959, 87.61704246774212), (-35.938136307374954, 75.66093807389606), (-44.3933389052322, -168.60378665284819), (62.51242162804334, 16.763212753007906), (62.29454792351788, -28.98580177999696), (-68.12183070983687, -158.6877916614261), (-7.791739137128147, 29.425763519872845), (42.38629980025354, -123.71141085122659), (73.32237836747515, 144.37090167370684), (-40.20543098470873, 70.5553031265508), (-56.49555306484043, 119.81447344127685), (75.0800951277125, -28.698045562303122), (34.985634435803505, -126.64557375601292), (27.13774780137574, -50.00972089588174), (-87.58150360950218, -26.331010890607104), (-28.167872032307102, 145.51882365515473), (63.65168234020015, 149.9651489452221), (38.94663269762037, 63.292697548988144), (-34.955996905372274, 117.25276048554792), (23.18003166115396, 66.84778829683816), (46.850509952691056, -160.60063291137428), (-65.54094053963371, -69.33215951317875), (85.63938083377982, -105.91296677337309), (45.109676094465215, -107.75485423072256), (17.86574093534803, 176.91252312001433), (-40.868136456553025, -48.09923774900824), (-38.77245050771564, 142.9369605421058), (84.5357596339762, -28.585284311161303), (74.76219204968137, -29.798178988302), (25.086387550393027, 67.51592935216803), (76.72630843828208, -123.39067876397542), (22.072121904199975, 137.31371237372463), (72.8203355093608, -7.3468323518277145), (25.130842122922118, -53.548748021906974), (46.774502490006284, -68.31972784801407), (-87.2073835403728, 3.616864285059762), (-87.28279466327588, -176.09155664311808), (47.3845209042226, 90.56568633394932), (17.999419938249403, -89.56123911278425), (-78.35745390789225, 125.25239731397176), (85.18431554875824, -99.42213023692494), (4.557075233768757, 152.77161497262836), (-87.27757082854927, -173.89998928624394), (56.46011907712443, -23.206006532745533), (-11.774325587345245, -4.21166192508872), (-6.271793161969484, 57.39981481414392), (-70.05214112079351, 130.55065127751072), (-14.52517502535622, 81.44264903962028), (-14.236949675059392, -46.47438787577053), (75.80719367862162, 145.59893594254845), (-21.986136722403003, -133.96410788938226), (-35.44015836679284, 144.29938958823925), (-82.09093351111292, 107.95546470824536), (68.66991970010764, 36.76008489480941), (88.67470972272483, 2.2686812473554028), (-16.565136827612363, 54.85995580380535), (2.559221289430525, -143.2959951825573), (-72.45953523115017, 58.20622611017984), (-81.53759405912042, -74.20900487651566), (-71.54479281659948, -163.01572125718374), (8.82049578512742, -135.6483073462098), (26.339738480104856, 81.96203497620468), (14.312368995783245, 36.65993609498284), (39.551555105985415, 152.1712902693763), (-89.65022330473641, 81.81953022239719), (8.8760772910682, 158.60672326058761), (-3.642606208698055, 97.89297980305406), (2.336137399051694, 49.756360600632064), (22.012699743258338, 52.449301766042566), (-61.98096730844371, -117.57179445956382), (-26.011939541646363, 114.18649159579996), (58.143793574027825, -40.4508255678962), (-71.07456646161874, -45.0265066800884), (78.07362877241712, -55.379339153140535), (-42.21161410966066, -17.597201802587108), (-18.375251709079294, 43.03441292529644), (84.01701042356055, 102.09109389107101), (30.29116649667847, -135.77215078284127), (-68.11226140966978, 113.7421266783183), (-56.99196184065512, 137.2891391148661), (-31.995613303729336, 92.98560805427377), (-8.90232644116415, 133.4679015176073), (-21.105785108821408, 30.6982936836597), (-33.65438299347463, -90.79249988451745), (78.79595553069481, -32.81024170329718), (84.2626162704137, 20.665342601400084), (43.78326527476068, 165.40507827533128), (13.829547664218467, 156.08977412665837), (46.124054234807744, 85.02241561406663), (-14.762348239312288, -23.883716849523807), (84.20907671850597, -56.802576139864314), (-37.93651009489253, 122.97998918961241), (-85.12377268422304, 146.3867765534281), (63.081041632537364, 136.1524372527278), (-36.923262204866944, -63.85630913845898), (-85.7467833284149, 171.9602153941584), (24.19622419 ...

# %%
# Begin URL for Weather API call
url = "http://api.openweathermap.org/data/2.5/weather?q={city name}&appid=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?q={city name}&appid=562484404a93d4baac7811b09c9df137

# %%
# !pip install citipy
# Out:
# Requirement already satisfied: citipy in c:\users\lawre\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\lawre\anaconda3\lib\site-packages (from citipy) (0.16)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Retrieve the following from the API call
# Create an empty list to hold the weather data.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
city_data = []
import time
import datetime

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | dikson
# Processing Record 2 of Set 1 | bambous virieux
# Processing Record 3 of Set 1 | vaini
# Processing Record 4 of Set 1 | timra
# Processing Record 5 of Set 1 | olafsvik
# Processing Record 6 of Set 1 | mataura
# Processing Record 7 of Set 1 | kaputa
# Processing Record 8 of Set 1 | grants pass
# Processing Record 9 of Set 1 | chokurdakh
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | half moon bay
# Processing Record 14 of Set 1 | codrington
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | roma
# Processing Record 17 of Set 1 | yagodnoye
# Processing Record 18 of Set 1 | turkmenabat
# Processing Record 19 of Set 1 | keti bandar
# Processing Record 20 of Set 1 | kodiak
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | sheridan
# Processing Record 23 of Set 1 | butaritari
# Processing Record 24 of Set 1 | rocha
# Processing Record 25 of Set 1 | warrnambool
# Processing Record 26 of Set 1 | gharo
# Processing Record 27 of Set 1 | norman wells
# Processing Record 28 of Set 1 | naze
# Processing Record 29 of Set 1 | klaksvik
# Processing Record 30 of Set 1 | presque isle
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | altay
# Processing Record 33 of Set 1 | nicolas bravo
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | kavieng
# Processing Record 36 of Set 1 | grindavik
# Processing Record 37 of Set 1 | jamestown
# Processing Record 38 of Set 1 | victoria
# Processing Record 39 of Set 1 | hithadhoo
# Processing Record 40 of Set 1 | posse
# Processing Record 41 of Set 1 | rikitea
# Processing Record 42 of Set 1 | deniliquin
# Processing Record 43 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 1 | saint-denis
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | sultanpur
# Processing Record 49 of Set 1 | himora
# City not found. Skipping...
# Processing Record 50 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 2 | busselton
# Processing Record 2 of Set 2 | padang
# Processing Record 3 of Set 2 | hobyo
# Processing Record 4 of Set 2 | abu dhabi
# Processing Record 5 of Set 2 | carnarvon
# Processing Record 6 of Set 2 | nanortalik
# Processing Record 7 of Set 2 | upernavik
# Processing Record 8 of Set 2 | morondava
# Processing Record 9 of Set 2 | khatanga
# Processing Record 10 of Set 2 | maningrida
# Processing Record 11 of Set 2 | chiredzi
# Processing Record 12 of Set 2 | lebu
# Processing Record 13 of Set 2 | longyearbyen
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | baijiantan
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | esperance
# Processing Record 18 of Set 2 | hobart
# Processing Record 19 of Set 2 | khandyga
# Processing Record 20 of Set 2 | santa rosa
# Processing Record 21 of Set 2 | bluff
# Processing Record 22 of Set 2 | atar
# Processing Record 23 of Set 2 | bealanana
# Processing Record 24 of Set 2 | punta arenas
# Processing Record 25 of Set 2 | ostrovnoy
# Processing Record 26 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 27 of Set 2 | kapoeta
# Processing Record 28 of Set 2 | mar del plata
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | guozhen
# Processing Record 31 of Set 2 | east london
# Processing Record 32 of Set 2 | qabis
# City not found. Skipping...
# Processing Record 33 of Set 2 | filadelfia
# Processing Record 34 of Set 2 | seguin
# Processing Record 35 of Set 2 | saldanha
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | paita
# Processing Record 38 of Set 2 | birao
# Processing Record 39 of Set 2 | kerema
# Processing Record 40 of Set 2 | vila velha
# Processing Record 41 of Set 2 | boysun
# Processing Record 42 of Set 2 | ketchikan
# Processing Record 43 of Set 2 | nome
# Processing Record 44 of Set 2 | sharan
# Processing Record 45 of Set 2 | wagar
# Processing Record 46 of Set 2 | castro
# Processing Record 47 of Set 2 | sao joao da barra
# Processing Record 48 of Set 2 | grand gaube
# Processing Record 49 of Set 2 | valparaiso
# Processing Record 50 of Set 2 | esna
# Processing Record 1 of Set 3 | dhandhuka
# Processing Record 2 of Set 3 | saint-philippe
# Processing Record 3 of Set 3 | anchorage
# Processing Record 4 of Set 3 | hamilton
# Processing Record 5 of Set 3 | homer
# Processing Record 6 of Set 3 | chumikan
# Processing Record 7 of Set 3 | hollola
# Processing Record 8 of Set 3 | puerto ayora
# Processing Record 9 of Set 3 | mogadishu
# Processing Record 10 of Set 3 | ponta do sol
# Processing Record 11 of Set 3 | bredasdorp
# Processing Record 12 of Set 3 | karratha
# Processing Record 13 of Set 3 | thilogne
# City not found. Skipping...
# Processing Record 14 of Set 3 | broken hill
# Processing Record 15 of Set 3 | plouzane
# Processing Record 16 of Set 3 | corbelia
# Processing Record 17 of Set 3 | lorengau
# Processing Record 18 of Set 3 | airai
# Processing Record 19 of Set 3 | batagay-alyta
# Processing Record 20 of Set 3 | camacha
# Processing Record 21 of Set 3 | kahului
# Processing Record 22 of Set 3 | ozinki
# Processing Record 23 of Set 3 | cape town
# Processing Record 24 of Set 3 | turayf
# Processing Record 25 of Set 3 | roald
# Processing Record 26 of Set 3 | yerbogachen
# Processing Record 27 of Set 3 | avarua
# Processing Record 28 of Set 3 | mama
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | port alfred
# Processing Record 31 of Set 3 | pangnirtung
# Processing Record 32 of Set 3 | malwan
# City not found. Skipping...
# Processing Record 33 of Set 3 | yar-sale
# Processing Record 34 of Set 3 | cockburn town
# Processing Record 35 of Set 3 | khanewal
# Processing Record 36 of Set 3 | sao filipe
# Processing Record 37 of Set 3 | peniche
# Processing Record 38 of Set 3 | qaanaaq
# Processing Record 39 of Set 3 | venezuela
# Processing Record 40 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 41 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 42 of Set 3 | bengkulu
# Processing Record 43 of Set 3 | cedar city
# Processing Record 44 of Set 3 | barrow
# Processing Record 45 of Set 3 | kruisfontein
# Processing Record 46 of Set 3 | tiksi
# Processing Record 47 of Set 3 | tuktoyaktuk
# Processing Record 48 of Set 3 | sitka
# Processing Record 49 of Set 3 | ilebo
# Processing Record 50 of Set 3 | kargasok
# Processing Record 1 of Set 4 | bayir
# Processing Record 2 of Set 4 | san patricio
# Processing Record 3 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 4 | takoradi
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | ucluelet
# Processing Record 7 of Set 4 | celestun
# Processing Record 8 of Set 4 | coetupo
# City not found. Skipping...
# Processing Record 9 of Set 4 | vardo
# Processing Record 10 of Set 4 | aklavik
# Processing Record 11 of Set 4 | ahipara
# Processing Record 12 of Set 4 | russell
# Processing Record 13 of Set 4 | tasiilaq
# Processing Record 14 of Set 4 | saskylakh
# Processing Record 15 of Set 4 | atbasar
# Processing Record 16 of Set 4 | upington
# Processing Record 17 of Set 4 | taoudenni
# Processing Record 18 of Set 4 | kotido
# Processing Record 19 of Set 4 | doha
# Processing Record 20 of Set 4 | valledupar
# Processing Record 21 of Set 4 | santa cruz
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | pisco
# Processing Record 24 of Set 4 | reconquista
# Processing Record 25 of Set 4 | ulladulla
# Processing Record 26 of Set 4 | coxim
# Processing Record 27 of Set 4 | kapaa
# Processing Record 28 of Set 4 | namwala
# Processing Record 29 of Set 4 | ambilobe
# Processing Record 30 of Set 4 | thompson
# Processing Record 31 of Set 4 | marawi
# Processing Record 32 of Set 4 | ponta delgada
# Processing Record 33 of Set 4 | saint-georges
# Processing Record 34 of Set 4 | san juan bautista
# Processing Record 35 of Set 4 | bayshore gardens
# Processing Record 36 of Set 4 | jati
# Processing Record 37 of Set 4 | severo-kurilsk
# Processing Record 38 of Set 4 | pala
# Processing Record 39 of Set 4 | husavik
# Processing Record 40 of Set 4 | cartagena
# Processing Record 41 of Set 4 | talnakh
# Processing Record 42 of Set 4 | heihe
# Processing Record 43 of Set 4 | gueret
# Processing Record 44 of Set 4 | gboko
# Processing Record 45 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 4 | iskateley
# Processing Record 47 of Set 4 | laramie
# Processing Record 48 of Set 4 | belaya gora
# Processing Record 49 of Set 4 | karkaralinsk
# City not found. Skipping...
# Processing Record 50 of Set 4 | isiro
# Processing Record 1 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 2 of Set 5 | lompoc
# Processing Record 3 of Set 5 | buala
# Processing Record 4 of Set 5 | burnie
# Processing Record 5 of Set 5 | san quintin
# Processing Record 6 of Set 5 | jinchengjiang
# City not found. Skipping...
# Processing Record 7 of Set 5 | namibe
# Processing Record 8 of Set 5 | ampanihy
# Processing Record 9 of Set 5 | quatre cocos
# Processing Record 10 of Set 5 | englewood
# Processing Record 11 of Set 5 | bandarbeyla
# Processing Record 12 of Set 5 | aguacatan
# Processing Record 13 of Set 5 | luyang
# Processing Record 14 of Set 5 | riberalta
# Processing Record 15 of Set 5 | west bay
# Processing Record 16 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 17 of Set 5 | torbay
# Processing Record 18 of Set 5 | lima
# Processing Record 19 of Set 5 | kaitangata
# Processing Record 20 of Set 5 | xihua
# Processing Record 21 of Set 5 | hasaki
# Processing Record 22 of Set 5 | mount gambier
# Processing Record 23 of Set 5 | palu
# Processing Record 24 of Set 5 | halifax
# Processing Record 25 of Set 5 | daru
# Processing Record 26 of Set 5 | haines junction
# Processing Record 27 of Set 5 | zhezkazgan
# Processing Record 28 of Set 5 | ayan
# Processing Record 29 of Set 5 | pochutla
# Processing Record 30 of Set 5 | cherskiy
# Processing Record 31 of Set 5 | geraldton
# Processing Record 32 of Set 5 | richards bay
# Processing Record 33 of Set 5 | lavrentiya
# Processing Record 34 of Set 5 | gustrow
# Processing Record 35 of Set 5 | owando
# Processing Record 36 of Set 5 | verkhnevilyuysk
# Processing Record 37 of Set 5 | fortuna
# Processing Record 38 of Set 5 | mocuba
# Processing Record 39 of Set 5 | vestmannaeyjar
# Processing Record 40 of Set 5 | diego de almagro
# Processing Record 41 of Set 5 | omboue
# Processing Record 42 of Set 5 | cayenne
# Processing Record 43 of Set 5 | deputatskiy
# Processing Record 44 of Set 5 | cabra
# Processing Record 45 of Set 5 | kegayli
# City not found. Skipping...
# Processing Record 46 of Set 5 | palmer
# Processing Record 47 of Set 5 | samoylovka
# Processing Record 48 of Set 5 | sochi
# Processing Record 49 of Set 5 | los llanos de aridane
# Processing Record 50 of Set 5 | dubti
# Processing Record 1 of Set 6 | koungou
# Processing Record 2 of Set 6 | jiujiang
# Processing Record 3 of Set 6 | havre-saint-pierre
# Processing Record 4 of Set 6 | lujan
# Processing Record 5 of Set 6 | la paz centro
# Processing Record 6 of Set 6 | le port
# Processing Record 7 of Set 6 | tevaitoa
# Processing Record 8 of Set 6 | ban nahin
# Processing Record 9 of Set 6 | ilulissat
# Processing Record 10 of Set 6 | zapolyarnyy
# Processing Record 11 of Set 6 | carutapera
# Processing Record 12 of Set 6 | bathsheba
# Processing Record 13 of Set 6 | girona
# Processing Record 14 of Set 6 | kirakira
# Processing Record 15 of Set 6 | mareeba
# Processing Record 16 of Set 6 | empalme
# Processing Record 17 of Set 6 | marathon
# Processing Record 18 of Set 6 | maesteg
# Processing Record 19 of Set 6 | temaraia
# City not found. Skipping...
# Processing Record 20 of Set 6 | broome
# Processing Record 21 of Set 6 | inuvik
# Processing Record 22 of Set 6 | rawson
# Processing Record 23 of Set 6 | santa cruz del sur
# Processing Record 24 of Set 6 | auki
# Processing Record 25 of Set 6 | sawakin
# Processing Record 26 of Set 6 | vangaindrano
# Processing Record 27 of Set 6 | bonthe
# Processing Record 28 of Set 6 | poim
# Processing Record 29 of Set 6 | acarau
# Processing Record 30 of Set 6 | sungairaya
# Processing Record 31 of Set 6 | salalah
# Processing Record 32 of Set 6 | iracoubo
# Processing Record 33 of Set 6 | lianyuan
# Processing Record 34 of Set 6 | talavera de la reina
# Processing Record 35 of Set 6 | port augusta
# Processing Record 36 of Set 6 | krasnoarmeysk
# Processing Record 37 of Set 6 | paamiut
# Processing Record 38 of Set 6 | puerto colombia
# Processing Record 39 of Set 6 | christiana
# Processing Record 40 of Set 6 | fort nelson
# Processing Record 41 of Set 6 | kieta
# Processing Record 42 of Set 6 | oranjemund
# Processing Record 43 of Set 6 | jian
# Processing Record 44 of Set 6 | lamar
# Processing Record 45 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 6 | port blair
# Processing Record 47 of Set 6 | tuatapere
# Processing Record 48 of Set 6 | arlit
# Processing Record 49 of Set 6 | teguise
# Processing Record 50 of Set 6 | hearst
# Processing Record 1 of Set 7 | clyde river
# Processing Record 2 of Set 7 | fare
# Processing Record 3 of Set 7 | luba
# Processing Record 4 of Set 7 | fayaoue
# Processing Record 5 of Set 7 | katangli
# Processing Record 6 of Set 7 | karlskrona
# Processing Record 7 of Set 7 | luderitz
# Processing Record 8 of Set 7 | san andres
# Processing Record 9 of Set 7 | komsomolskiy
# Processing Record 10 of Set 7 | dalvik
# Processing Record 11 of Set 7 | whitehorse
# Processing Record 12 of Set 7 | flinders
# Processing Record 13 of Set 7 | sisimiut
# Processing Record 14 of Set 7 | southbridge
# Processing Record 15 of Set 7 | hambantota
# Processing Record 16 of Set 7 | guarapari
# Processing Record 17 of Set 7 | loandjili
# Processing Record 18 of Set 7 | shingu
# Processing Record 19 of Set 7 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 7 | eydhafushi
# Processing Record 21 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 22 of Set 7 | viesca
# Processing Record 23 of Set 7 | beloha
# Processing Record 24 of Set 7 | champerico
# Processing Record 25 of Set 7 | alta gracia
# Processing Record 26 of Set 7 | rio grande
# Processing Record 27 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 7 | provideniya
# Processing Record 29 of Set 7 | cacu
# Processing Record 30 of Set 7 | nea stira
# Processing Record 31 of Set 7 | bilma
# Processing Record 32 of Set 7 | linkou
# Processing Record 33 of Set 7 | imbituba
# Processing Record 34 of Set 7 | stabat
# Processing Record 35 of Set 7 | iqaluit
# Processing Record 36 of Set 7 | minab
# Processing Record 37 of Set 7 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 7 | medicine hat
# Processing Record 39 of Set 7 | kracheh
# City not found. Skipping...
# Processing Record 40 of Set 7 | tocopilla
# Processing Record 41 of Set 7 | faanui
# Processing Record 42 of Set 7 | kunda
# Processing Record 43 of Set 7 | dezful
# Processing Record 44 of Set 7 | chernyshevskiy
# Processing Record 45 of Set 7 | ust-nera
# Processing Record 46 of Set 7 | vicuna
# Processing Record 47 of Set 7 | umm lajj
# Processing Record 48 of Set 7 | xinqing
# Processing Record 49 of Set 7 | mehamn
# Processing Record 50 of Set 7 | comodoro rivadavia
# Processing Record 1 of Set 8 | pismo beach
# Processing Record 2 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 3 of Set 8 | colares
# Processing Record 4 of Set 8 | himare
# Processing Record 5 of Set 8 | cabo san lucas
# Processing Record 6 of Set 8 | polson
# Processing Record 7 of Set 8 | kutum
# Processing Record 8 of Set 8 | constitucion
# Processing Record 9 of Set 8 | maryborough
# Processing Record 10 of Set 8 | araouane
# Processing Record 11 of Set 8 | port keats
# Processing Record 12 of Set 8 | mahadday weyne
# City not found. Skipping...
# Processing Record 13 of Set 8 | coquimbo
# Processing Record 14 of Set 8 | taft
# Processing Record 15 of Set 8 | lufilufi
# Processing Record 16 of Set 8 | puerto penasco
# Processing Record 17 of Set 8 | ono
# Processing Record 18 of Set 8 | srednyaya yelyuzan
# Processing Record 19 of Set 8 | magui
# City not found. Skipping...
# Processing Record 20 of Set 8 | jiddah
# City not found. Skipping...
# Processing Record 21 of Set 8 | pudozh
# Processing Record 22 of Set 8 | uravakonda
# Processing Record 23 of Set 8 | muisne
# Processing Record 24 of Set 8 | thohoyandou
# Processing Record 25 of Set 8 | caravelas
# Processing Record 26 of Set 8 | guerrero negro
# Processing Record 27 of Set 8 | aripuana
# Processing Record 28 of Set 8 | katsuura
# Processing Record 29 of Set 8 | maghama
# City not found. Skipping...
# Processing Record 30 of Set 8 | svetlaya
# Processing Record 31 of Set 8 | burica
# City not found. Skipping...
# Processing Record 32 of Set 8 | mahina
# Processing Record 33 of Set 8 | salas
# Processing Record 34 of Set 8 | bontang
# Processing Record 35 of Set 8 | luwuk
# Processing Record 36 of Set 8 | ajdabiya
# Processing Record 37 of Set 8 | bowen
# Processing Record 38 of Set 8 | mackay
# Processing Record 39 of Set 8 | zarubino
# Processing Record 40 of Set 8 | entre rios
# Processing Record 41 of Set 8 | marsh harbour
# Processing Record 42 of Set 8 | flin flon
# Processing Record 43 of Set 8 | alugan
# Processing Record 44 of Set 8 | narsaq
# Processing Record 45 of Set 8 | baghdad
# Processing Record 46 of Set 8 | cervo
# Processing Record 47 of Set 8 | kholmogory
# Processing Record 48 of Set 8 | palaia fokaia
# Processing Record 49 of Set 8 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 8 | areosa
# Processing Record 1 of Set 9 | abeche
# Processing Record 2 of Set 9 | knysna
# Processing Record 3 of Set 9 | fernandina beach
# Processing Record 4 of Set 9 | tahta
# Processing Record 5 of Set 9 | buchanan
# Processing Record 6 of Set 9 | capiibary
# Processing Record 7 of Set 9 | kenitra
# Processing Record 8 of Set 9 | berezovka
# Processing Record 9 of Set 9 | hazorasp
# Processing Record 10 of Set 9 | miandrivazo
# Processing Record 11 of Set 9 | zheleznodorozhnyy
# Processing Record 12 of Set 9 | tasbuget
# City not found. Skipping...
# Processing Record 13 of Set 9 | zalesovo
# Processing Record 14 of Set 9 | margate
# Processing Record 15 of Set 9 | parana
# Processing Record 16 of Set 9 | wisconsin rapids
# Processing Record 17 of Set 9 | namatanai
# Processing Record 18 of Set 9 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 9 | mocajuba
# Processing Record 20 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 21 of Set 9 | port macquarie
# Processing Record 22 of Set 9 | bayan
# Processing Record 23 of Set 9 | tahoua
# Processing Record 24 of Set 9 | itarema
# Processing Record 25 of Set 9 | kitui
# Processing Record 26 of Set 9 | stanceni
# Processing Record 27 of Set 9 | sangar
# Processing Record 28 of Set 9 | urucara
# Processing Record 29 of Set 9 | yining
# Processing Record 30 of Set 9 | avera
# Processing Record 31 of Set 9 | ileza
# Processing Record 32 of Set 9 | dauriya
# Processing Record 33 of Set 9 | ribeira grande
# Processing Record 34 of Set 9 | snyder
# Processing Record 35 of Set 9 | bairiki
# Processing Record 36 of Set 9 | crowley
# Processing Record 37 of Set 9 | tveit
# Processing Record 38 of Set 9 | arraial do cabo
# Processing Record 39 of Set 9 | sorland
# Processing Record 40 of Set 9 | sur
# Processing Record 41 of Set 9 | karpathos
# Processing Record 42 of Set 9 | andenes
# Processing Record 43 of Set 9 | swan hill
# Processing Record 44 of Set 9 | chegdomyn
# Processing Record 45 of Set 9 | okha
# Processing Record 46 of Set 9 | pochinki
# Processing Record 47 of Set 9 | malinovskiy
# Processing Record 48 of Set 9 | duncan
# Processing Record 49 of Set 9 | saint-joseph
# Processing Record 50 of Set 9 | mount isa
# Processing Record 1 of Set 10 | gawan
# Processing Record 2 of Set 10 | acajutla
# Processing Record 3 of Set 10 | yaan
# Processing Record 4 of Set 10 | linjiang
# Processing Record 5 of Set 10 | samarai
# Processing Record 6 of Set 10 | souillac
# Processing Record 7 of Set 10 | bima
# Processing Record 8 of Set 10 | burgeo
# Processing Record 9 of Set 10 | bagdarin
# Processing Record 10 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 11 of Set 10 | japura
# Processing Record 12 of Set 10 | pevek
# Processing Record 13 of Set 10 | maridi
# Processing Record 14 of Set 10 | rio claro
# Processing Record 15 of Set 10 | xuanhua
# Processing Record 16 of Set 10 | yarmouth
# Processing Record 17 of Set 10 | shache
# Processing Record 18 of Set 10 | tsiroanomandidy
# Processing Record 19 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 20 of Set 10 | halle
# Processing Record 21 of Set 10 | alofi
# Processing Record 22 of Set 10 | harper
# Processing Record 23 of Set 10 | waingapu
# Processing Record 24 of Set 10 | sarkand
# Processing Record 25 of Set 10 | westport
# Processing Record 26 of Set 10 | luchegorsk
# Processing Record 27 of Set 10 | pingxiang
# Processing Record 28 of Set 10 | kosa
# Processing Record 29 of Set 10 | cranbrook
# Processing Record 30 of Set 10 | usinsk
# Processing Record 31 of Set 10 | ola
# Processing Record 32 of Set 10 | kavaratti
# Processing Record 33 of Set 10 | sikeai
# City not found. Skipping...
# Processing Record 34 of Set 10 | alotau
# City not found. Skipping...
# Processing Record 35 of Set 10 | horki
# Processing Record 36 of Set 10 | kamina
# Processing Record 37 of Set 10 | west wendover
# Processing Record 38 of Set 10 | newtownards
# Processing Record 39 of Set 10 | morehead
# Processing Record 40 of Set 10 | general roca
# Processing Record 41 of Set 10 | korla
# Processing Record 42 of Set 10 | coruripe
# Processing Record 43 of Set 10 | boa vista
# Processing Record 44 of Set 10 | lancaster
# Processing Record 45 of Set 10 | baykit
# Processing Record 46 of Set 10 | antalaha
# Processing Record 47 of Set 10 | wahiawa
# Processing Record 48 of Set 10 | hofn
# Processing Record 49 of Set 10 | erenhot
# Processing Record 50 of Set 10 | ipixuna
# Processing Record 1 of Set 11 | biscarrosse
# Processing Record 2 of Set 11 | dingle
# Processing Record 3 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 4 of Set 11 | poum
# Processing Record 5 of Set 11 | ballina
# Processing Record 6 of Set 11 | sao jose da coroa grande
# Processing Record 7 of Set 11 | chimoio
# Processing Record 8 of Set 11 | sinnamary
# Processing Record 9 of Set 11 | sibolga
# Processing Record 10 of Set 11 | pouebo
# Processing Record 11 of Set 11 | bethel
# Processing Record 12 of Set 11 | wamba
# Processing Record 13 of Set 11 | tevriz
# Processing Record 14 of Set 11 | inhambane
# Processing Record 15 of Set 11 | luanda
# Processing Record 16 of Set 11 | awjilah
# Processing Record 17 of Set 11 | kuusamo
# Processing Record 18 of Set 11 | gberia fotombu
# Processing Record 19 of Set 11 | coahuayana
# Processing Record 20 of Set 11 | chuy
# Processing Record 21 of Set 11 | fukue
# Processing Record 22 of Set 11 | curup
# Processing Record 23 of Set 11 | muros
# Processing Record 24 of Set 11 | sao joao dos patos
# Processing Record 25 of Set 11 | ovruch
# Processing Record 26 of Set 11 | matadi
# Processing Record 27 of Set 11 | natal
# Processing Record 28 of Set 11 | villanueva
# Processing Record 29 of Set 11 | riyadh
# Processing Record 30 of Set 11 | puno
# Processing Record 31 of Set 11 | lyngseidet
# Processing Record 32 of Set 11 | sal rei
# Processing Record 33 of Set 11 | moree
# Processing Record 34 of Set 11 | nishihara
# Processing Record 35 of Set 11 | beyla
# Processing Record 36 of Set 11 | srandakan
# Processing Record 37 of Set 11 | callaway
# Processing Record 38 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 39 of Set 11 | ancud
# Processing Record 40 of Set 11 | kapit
# Processing Record 41 of Set 11 | tokur
# Processing Record 42 of Set 11 | kununurra
# Processing Record 43 of Set 11 | saint-leu
# Processing Record 44 of Set 11 | alappuzha
# Processing Record 45 of Set 11 | serowe
# Processing Record 46 of Set 11 | la peca
# Processing Record 47 of Set 11 | kovur
# Processing Record 48 of Set 11 | turan
# Processing Record 49 of Set 11 | maniitsoq
# Processing Record 50 of Set 11 | tiznit
# Processing Record 1 of Set 12 | tongren
# Processing Record 2 of Set 12 | waitati
# Processing Record 3 of Set 12 | muhos
# Processing Record 4 of Set 12 | zhigansk
# Processing Record 5 of Set 12 | huarmey
# Processing Record 6 of Set 12 | asau
# Processing Record 7 of Set 12 | labuhan
# Processing Record 8 of Set 12 | saint anthony
# Processing Record 9 of Set 12 | mangai
# Processing Record 10 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 11 of Set 12 | coihaique
# Processing Record 12 of Set 12 | praxedis guerrero
# Processing Record 13 of Set 12 | muhammadabad
# Processing Record 14 of Set 12 | igarka
# Processing Record 15 of Set 12 | candiis
# Processing Record 16 of Set 12 | saint-ambroise
# Processing Record 17 of Set 12 | paradise valley
# Processing Record 18 of Set 12 | havelock
# Processing Record 19 of Set 12 | mbekenyera
# Processing Record 20 of Set 12 | sao felix do xingu
# Processing Record 21 of Set 12 | srednekolymsk
# Processing Record 22 of Set 12 | vestmanna
# Processing Record 23 of Set 12 | kachug
# Processing Record 24 of Set 12 | clinton
# Processing Record 25 of Set 12 | oranjestad
# Processing Record 26 of Set 12 | beringovskiy
# Processing Record 27 of Set 12 | tumsar
# Processing Record 28 of Set 12 | goderich
# Processing Record 29 of Set 12 | matinhos
# Processing Record 30 of Set 12 | lesnoy
# Processing Record 31 of Set 12 | jalu
# Processing Record 32 of Set 12 | tamiahua
# Processing Record 33 of Set 12 | faya
# Processing Record 34 of Set 12 | khudumelapye
# Processing Record 35 of Set 12 | lang son
# Processing Record 36 of Set 12 | nanga eboko
# Processing Record 37 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 38 of Set 12 | dunedin
# Processing Record 39 of Set 12 | bilibino
# Processing Record 40 of Set 12 | zhanatas
# City not found. Skipping...
# Processing Record 41 of Set 12 | general pico
# Processing Record 42 of Set 12 | bastia
# Processing Record 43 of Set 12 | anadyr
# Processing Record 44 of Set 12 | saint-louis
# Processing Record 45 of Set 12 | matongo
# Processing Record 46 of Set 12 | aromashevo
# Processing Record 47 of Set 12 | tautira
# Processing Record 48 of Set 12 | chipata
# Processing Record 49 of Set 12 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 50 of Set 12 | adrar
# Processing Record 1 of Set 13 | canon city
# Processing Record 2 of Set 13 | lasa
# Processing Record 3 of Set 13 | qadirpur ran
# Processing Record 4 of Set 13 | bereznik
# Processing Record 5 of Set 13 | rorvik
# Processing Record 6 of Set 13 | xunchang
# Processing Record 7 of Set 13 | canar
# Processing Record 8 of Set 13 | nouadhibou
# Processing Record 9 of Set 13 | uvalde
# Processing Record 10 of Set 13 | tashtyp
# Processing Record 11 of Set 13 | banda aceh
# Processing Record 12 of Set 13 | maragogi
# Processing Record 13 of Set 13 | rolim de moura
# City not found. Skipping...
# Processing Record 14 of Set 13 | laguna
# Processing Record 15 of Set 13 | sitrah
# Processing Record 16 of Set 13 | cumaribo
# City not found. Skipping...
# Processing Record 17 of Set 13 | itoman
# Processing Record 18 of Set 13 | la ronge
# Processing Record 19 of Set 13 | skjervoy
# Processing Record 20 of Set 13 | baley
# Processing Record 21 of Set 13 | san vicente
# Processing Record 22 of Set 13 | pak thong chai
# Processing Record 23 of Set 13 | casa nova
# Processing Record 24 of Set 13 | galle
# Processing Record 25 of Set 13 | gamba
# Processing Record 26 of Set 13 | kharp
# Processing Record 27 of Set 13 | vila franca do campo
# Processing Record 28 of Set 13 | vao
# Processing Record 29 of Set 13 | hirara
# Processing Record 30 of Set 13 | leningradskiy
# Processing Record 31 of Set 13 | vilhena
# Processing Record 32 of Set 13 | carroll
# Processing Record 33 of Set 13 | nantucket
# Processing Record 34 of Set 13 | mayo
# Processing Record 35 of Set 13 | sesheke
# Processing Record 36 of Set 13 | kantunilkin
# Processing Record 37 of Set 13 | sampit
# Processing Record 38 of Set 13 | fayetteville
# Processing Record 39 of Set 13 | sterling
# Processing Record 40 of Set 13 | atakpame
# Processing Record 41 of Set 13 | wangqing
# Processing Record 42 of Set 13 | walvis bay
# Processing Record 43 of Set 13 | pringsewu
# Processing Record 44 of Set 13 | kozlovo
# Processing Record 45 of Set 13 | kathmandu
# Processing Record 46 of Set 13 | sonoita
# Processing Record 47 of Set 13 | aginskoye
# Processing Record 48 of Set 13 | kendari
# Processing Record 49 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 13 | remanso
# Processing Record 1 of Set 14 | touros
# Processing Record 2 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 3 of Set 14 | tres de maio
# Processing Record 4 of Set 14 | thinadhoo
# Processing Record 5 of Set 14 | virginia beach
# Processing Record 6 of Set 14 | buseresere
# Processing Record 7 of Set 14 | uk
# City not found. Skipping...
# Processing Record 8 of Set 14 | san
# Processing Record 9 of Set 14 | kalakamati
# Processing Record 10 of Set 14 | mildura
# Processing Record 11 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 12 of Set 14 | stettler
# Processing Record 13 of Set 14 | mahbubabad
# Processing Record 14 of Set 14 | caucaia
# Processing Record 15 of Set 14 | karamea
# City not found. Skipping...
# Processing Record 16 of Set 14 | mamlyutka
# Processing Record 17 of Set 14 | lakitelek
# Processing Record 18 of Set 14 | cascais
# Processing Record 19 of Set 14 | tuensang
# Processing Record 20 of Set 14 | nkayi
# Processing Record 21 of Set 14 | pocoes
# Processing Record 22 of Set 14 | brae
# Processing Record 23 of Set 14 | gangotri
# City not found. Skipping...
# Processing Record 24 of Set 14 | erzin
# Processing Record 25 of Set 14 | berlevag
# Processing Record 26 of Set 14 | sambava
# Processing Record 27 of Set 14 | smidovich
# City not found. Skipping...
# Processing Record 28 of Set 14 | glendive
# Processing Record 29 of Set 14 | tual
# Processing Record 30 of Set 14 | parnamirim
# Processing Record 31 of Set 14 | sayyan
# Processing Record 32 of Set 14 | qingquan
# Processing Record 33 of Set 14 | acari
# Processing Record 34 of Set 14 | dagua
# Processing Record 35 of Set 14 | moose factory
# Processing Record 36 of Set 14 | kulhudhuffushi
# Processing Record 37 of Set 14 | svetlyy
# Processing Record 38 of Set 14 | nchelenge
# Processing Record 39 of Set 14 | waverly
# Processing Record 40 of Set 14 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 41 of Set 14 | funadhoo
# Processing Record 42 of Set 14 | la playa
# Processing Record 43 of Set 14 | nizhnevartovsk
# Processing Record 44 of Set 14 | billings
# Processing Record 45 of Set 14 | neepawa
# Processing Record 46 of Set 14 | chapais
# Processing Record 47 of Set 14 | iquique
# Processing Record 48 of Set 14 | akcakoca
# Processing Record 49 of Set 14 | kasongo-lunda
# Processing Record 50 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 15 | nuuk
# Processing Record 2 of Set 15 | garowe
# Processing Record 3 of Set 15 | dinard
# Processing Record 4 of Set 15 | neiafu
# Processing Record 5 of Set 15 | ulaangom
# Processing Record 6 of Set 15 | angoche
# Processing Record 7 of Set 15 | valera
# Processing Record 8 of Set 15 | havoysund
# Processing Record 9 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 15 | pueblo
# Processing Record 11 of Set 15 | umm kaddadah
# Processing Record 12 of Set 15 | naftah
# City not found. Skipping...
# Processing Record 13 of Set 15 | silleda
# Processing Record 14 of Set 15 | aasiaat
# Processing Record 15 of Set 15 | monrovia
# Processing Record 16 of Set 15 | evensk
# Processing Record 17 of Set 15 | the valley
# Processing Record 18 of Set 15 | tamandare
# Processing Record 19 of Set 15 | moyobamba
# Processing Record 20 of Set 15 | manggar
# Processing Record 21 of Set 15 | marzuq
# Processing Record 22 of Set 15 | san cristobal
# Processing Record 23 of Set 15 | ouadda
# Processing Record 24 of Set 15 | coaldale
# Processing Record 25 of Set 15 | lodja
# Processing Record 26 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 27 of Set 15 | darhan
# Processing Record 28 of Set 15 | yeppoon
# Processing Record 29 of Set 15 | sao joao do paraiso
# Processing Record 30 of Set 15 | baherden
# Processing Record 31 of Set 15 | matara
# Processing Record 32 of Set 15 | miraflores
# Processing Record 33 of Set 15 | stromness
# Processing Record 34 of Set 15 | port-gentil
# Processing Record 35 of Set 15 | pacific grove
# Processing Record 36 of Set 15 | bjornevatn
# Processing Record 37 of Set 15 | nabire
# Processing Record 38 of Set 15 | wakkanai
# Processing Record 39 of Set 15 | acapulco
# Processing Record 40 of Set 15 | kitimat
# Processing Record 41 of Set 15 | turukhansk
# Processing Record 42 of Set 15 | minden
# Processing Record 43 of Set 15 | rincon
# Processing Record 44 of Set 15 | gerash
# Processing Record 45 of Set 15 | chamalieres
# Processing Record 46 of Set 15 | lokken verk
# City not found. Skipping...
# Processing Record 47 of Set 15 | rio gallegos
# Processing Record 48 of Set 15 | dudinka
# Processing Record 49 of Set 15 | salinas
# Processing Record 50 of Set 15 | biloela
# Processing Record 1 of Set 16 | micheweni
# Processing Record 2 of Set 16 | kudahuvadhoo
# Processing Record 3 of Set 16 | varhaug
# Processing Record 4 of Set 16 | mizdah
# Processing Record 5 of Set 16 | alyangula
# Processing Record 6 of Set 16 | azimur
# City not found. Skipping...
# Processing Record 7 of Set 16 | bitung
# Processing Record 8 of Set 16 | bernay
# Processing Record 9 of Set 16 | yamada
# Processing Record 10 of Set 16 | leshukonskoye
# Processing Record 11 of Set 16 | kytmanovo
# Processing Record 12 of Set 16 | eten
# Processing Record 13 of Set 16 | lewisporte
# Processing Record 14 of Set 16 | jega
# Processing Record 15 of Set 16 | north bend
# Processing Record 16 of Set 16 | dekar
# Processing Record 17 of Set 16 | camargo
# Processing Record 18 of Set 16 | mon
# Processing Record 19 of Set 16 | tessalit
# Processing Record 20 of Set 16 | corrente
# Processing Record 21 of Set 16 | numan
# Processing Record 22 of Set 16 | nueva loja
# Processing Record 23 of Set 16 | galchino
# City not found. Skipping...
# Processing Record 24 of Set 16 | lugazi
# Processing Record 25 of Set 16 | esso
# Processing Record 26 of Set 16 | ixtapa
# Processing Record 27 of Set 16 | furano
# Processing Record 28 of Set 16 | shar
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Tally the number of cities in the city_data array of dictionaries
len(city_data)
# Out:
# 714

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Dikson  73.5069   80.5464    -13.05        97         100
# 1  Bambous Virieux -20.3428   57.7575     77.25        94          75
# 2            Vaini -21.2000 -175.2000     77.16       100         100
# 3            Timra  62.4870   17.3257     19.11        92         100
# 4         Olafsvik  64.8945  -23.7142     29.12        92         100
# 5          Mataura -46.1927  168.8643     60.48        34           8
# 6           Kaputa  -8.4689   29.6619     67.15        90         100
# 7      Grants Pass  42.4390 -123.3284     55.49        73           0
# 8       Chokurdakh  70.6333  147.9167    -39.73        99          79
# 9        Mahebourg -20.4081   57.7000     78.26        82         100
#
#    Wind Speed Country                 Date
# 0       16.33      RU  2022-02-07 02:56:51
# 1        3.44      MU  2022-02-07 02:58:18
# 2       11.50      TO  2022-02-07 02:58:16
# 3        3.44      SE  2022-02-07 03:01:49
# 4       37.27      IS  2022-02-07 02:56:30
# 5        2.75      NZ  2022-02-07 02:55:43
# 6        2.71      ZM  2022-02-07 03:01:50
# 7        1.01      US  2022-02-07 03:01:50
# 8        3.85      RU  2022-02-07 03:00:47
# 9       11.21      MU  2022-02-07 03:01:07

# %%
# Export the DataFrame to a CSV file, save it as WeatherPy_Database.csv in the Weather_Database folder
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"

# Export the City_Data to a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
