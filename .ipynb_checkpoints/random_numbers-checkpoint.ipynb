# %%
# Import the random module.
import random

# %%
random.randint(-90, 90)
# Out:
# -89

# %%
random.random()
# Out:
# 0.2506373604975203

# %%
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# -3.3937389758173935

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
random.randrange(-90, 90, step=1)
# Out:
# -14

# %%
random.randrange(-90, 90, step=3)
# Out:
# -18

# %%
random.uniform(-90, 90)
# Out:
# 49.57399478913035

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# -69.09691767300578

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([-17.29632771,  82.18790717, -40.91827846,  -9.27259298,
#        -81.91205673,  74.31020546,  29.14516787,  81.67085786,
#        -66.88329892, -61.58378884, -21.82829985, -10.73391536,
#        -53.32393102, -29.42096316,  -6.07435982,  81.26499233,
#         57.24427649,  69.53077006, -45.66758472,   8.07920639,
#         70.3718354 ,  -6.74349869, -58.58124579,  38.22195284,
#        -24.07547663,  38.0778238 ,  75.90723462, -66.258429  ,
#        -36.82386449, -51.33113207,  14.83437594, -36.52629947,
#         60.85941615,  63.5341465 ,  -2.75853952,   9.93808315,
#         -3.86519964, -88.65550316, -28.25168957,  21.12873219,
#        -71.95533675, -84.72302417,  -3.95597257, -21.81858439,
#         80.57917452, -22.85299942, -68.52100384, -60.54407203,
#         64.36554145, -15.57373226])

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 29.6 µs ± 2.3 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 3.01 ms ± 106 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# kapaa us
# samusu ws
# biloela au
# nizhneyansk ru
# provideniya ru
# opuwo na
# pangkalanbuun id
# acapulco mx
# gat ly
# ancud cl
# bluff nz
# saint-philippe re
# gravelbourg ca
# ushuaia ar
# arraial do cabo br
# ancud cl
# waiouru nz
# georgetown sh
# rikitea pf
# bengkulu id
# biltine td
# oksfjord no
# georgetown sh
# rikitea pf
# san patricio mx
# baruun-urt mn
# tasiilaq gl
# new norfolk au
# arraial do cabo br
# ushuaia ar
# meshcherino ru
# vaitupu wf
# barentsburg sj
# airai pw
# kapaa us
# olafsvik is
# ushuaia ar
# vaini to
# casper us
# mahadday weyne so
# tucuman ar
# qaanaaq gl
# ribeira grande pt
# port hawkesbury ca
# kaniama cd
# hermanus za
# san quintin mx
# rikitea pf
# arraial do cabo br
# new norfolk au
# yellowknife ca
# kruisfontein za
# ulladulla au
# kodiak us
# hasaki jp
# kapaa us
# pierre us
# shimanovsk ru
# arkul ru
# tsihombe mg
# chokurdakh ru
# sungairaya id
# tarudant ma
# kapaa us
# souillac mu
# rabo de peixe pt
# salamanca es
# esperance au
# upernavik gl
# arraial do cabo br
# airai pw
# saint-philippe re
# valerianovsk ru
# mataura pf
# nabire id
# qaanaaq gl
# saint-philippe re
# puerto ayora ec
# avarua ck
# albany au
# rikitea pf
# jamestown sh
# amahai id
# hilo us
# mackenzie ca
# punta arenas cl
# kokopo pg
# ridgecrest us
# castro cl
# kloulklubed pw
# tasiilaq gl
# dien bien vn
# castro cl
# kobojango bw
# bambous virieux mu
# kapaa us
# hobart au
# mataura pf
# moshkovo ru
# ushuaia ar
# araouane ml
# jacareacanga br
# tasiilaq gl
# kruisfontein za
# port alfred za
# komsomolskiy ru
# mumford gh
# taolanaro mg
# lebu cl
# cape town za
# jamestown sh
# vaitupu wf
# noyabrsk ru
# mys shmidta ru
# ganzhou cn
# atar mr
# ancud cl
# piacabucu br
# klaksvik fo
# port elizabeth za
# talnakh ru
# bintulu my
# novokizhinginsk ru
# port alfred za
# jamestown sh
# avarua ck
# katsuura jp
# rikitea pf
# castro cl
# severo-kurilsk ru
# cap malheureux mu
# cape town za
# punta arenas cl
# durban za
# kedrovyy ru
# jamestown sh
# kruisfontein za
# kahului us
# jamestown sh
# avarua ck
# mar del plata ar
# chokurdakh ru
# kamogawa jp
# busselton au
# rikitea pf
# puerto leguizamo co
# minab ir
# iqaluit ca
# punta arenas cl
# husavik is
# yarada in
# pundaguitan ph
# ulaangom mn
# georgetown sh
# bredasdorp za
# grand river south east mu
# port alfred za
# hobyo so
# san patricio mx
# cam ranh vn
# taolanaro mg
# kamenka ru
# norman wells ca
# cape town za
# ushuaia ar
# tiksi ru
# butaritari ki
# saskylakh ru
# bethel us
# faanui pf
# huanuni bo
# tuktoyaktuk ca
# saskylakh ru
# isangel vu
# maceio br
# atuona pf
# cape town za
# ovsyanka ru
# peniche pt
# ekibastuz kz
# sorong id
# severo-kurilsk ru
# qaanaaq gl
# vaini to
# puerto ayora ec
# avarua ck
# batemans bay au
# cape town za
# jamestown sh
# talara pe
# mount gambier au
# valparaiso cl
# chastoozerye ru
# rikitea pf
# rawlins us
# hohhot cn
# rolim de moura br
# hambantota lk
# atambua id
# vaini to
# sao felix do xingu br
# cape town za
# mataura pf
# ushuaia ar
# mataura pf
# vila velha br
# yellowknife ca
# puerto ayora ec
# brae gb
# hailin cn
# taolanaro mg
# kamalganj in
# hermanus za
# faanui pf
# kodiak us
# hermanus za
# ushuaia ar
# salalah om
# opuwo na
# rikitea pf
# bredasdorp za
# nikolskoye ru
# busselton au
# hermanus za
# grand river south east mu
# arraial do cabo br
# baglan af
# mataura pf
# mataura pf
# saint-philippe re
# roma au
# adrar dz
# mataura pf
# sao filipe cv
# cuamba mz
# cape town za
# taolanaro mg
# punta arenas cl
# vaini to
# lebu cl
# busselton au
# ostrovnoy ru
# arraial do cabo br
# chokurdakh ru
# yar-sale ru
# vardo no
# bokspits bw
# atasu kz
# airai pw
# ushuaia ar
# bredasdorp za
# port alfred za
# mataura pf
# telemaco borba br
# sungurlu tr
# half moon bay us
# sept-iles ca
# fortuna us
# hermanus za
# rikitea pf
# east london za
# ushuaia ar
# hermanus za
# diebougou bf
# jose de freitas br
# san vicente ph
# nikolskoye ru
# diego de almagro cl
# vanimo pg
# boyolangu id
# sisimiut gl
# solnechnyy ru
# rikitea pf
# victoria sc
# cabedelo br
# bethel us
# new norfolk au
# atuona pf
# ushuaia ar
# hobart au
# jilib so
# naze jp
# bambous virieux mu
# maldonado uy
# hobart au
# bredasdorp za
# norman wells ca
# port alfred za
# bluff nz
# blacksburg us
# ketchikan us
# port shepstone za
# woodward us
# bilma ne
# mataura pf
# fangshan cn
# gboko ng
# acapulco mx
# ushuaia ar
# coquimbo cl
# lima pe
# ancud cl
# vaini to
# namibe ao
# turayf sa
# busselton au
# jamestown sh
# kapaa us
# ushuaia ar
# lavrentiya ru
# souillac mu
# albany au
# sorland no
# belushya guba ru
# lorengau pg
# bredasdorp za
# vaini to
# bredasdorp za
# georgetown sh
# walvis bay na
# tautira pf
# port alfred za
# columbus us
# hamilton bm
# bredasdorp za
# bathsheba bb
# mataura pf
# kapaa us
# ushuaia ar
# albany au
# kapaa us
# merauke id
# poronaysk ru
# kaitangata nz
# kahului us
# hobart au
# lompoc us
# talnakh ru
# busselton au
# mataura pf
# mataura pf
# mercedes uy
# hithadhoo mv
# juxian cn
# halalo wf
# vaini to
# iqaluit ca
# mahebourg mu
# hermanus za
# hilo us
# bredasdorp za
# skelleftea se
# gorele tr
# bredasdorp za
# tartagal ar
# yulara au
# woodward us
# itoman jp
# jamestown sh
# leningradskiy ru
# khatanga ru
# dikson ru
# bure et
# lovington us
# manjeshwar in
# busselton au
# tilichiki ru
# rikitea pf
# erzin ru
# yellowknife ca
# sochi ru
# cabra ph
# miri my
# staunton us
# hermanus za
# ondangwa na
# komsomolskiy ru
# kapaa us
# punta arenas cl
# coihueco cl
# belushya guba ru
# port alfred za
# kapaa us
# albany au
# kangaatsiaq gl
# saint-philippe re
# atuona pf
# puerto ayora ec
# new norfolk au
# acapulco mx
# hilo us
# narsaq gl
# anori br
# comodoro rivadavia ar
# oksfjord no
# nantucket us
# ushuaia ar
# ruatoria nz
# ushuaia ar
# kaitangata nz
# busselton au
# joshimath in
# hovd mn
# ashoknagar in
# ellensburg us
# hobart au
# bluff nz
# inderborskiy kz
# coquimbo cl
# port alfred za
# albany au
# bluff nz
# tigil ru
# vaini to
# nome us
# wa gh
# kleck by
# thompson ca
# busselton au
# cape town za
# taolanaro mg
# chulym ru
# salym ru
# puerto ayora ec
# saint-philippe re
# severo-kurilsk ru
# cape town za
# rikitea pf
# zhengjiatun cn
# twentynine palms us
# belushya guba ru
# bongandanga cd
# thompson ca
# rikitea pf
# siyabuswa za
# taolanaro mg
# mataura pf
# cherskiy ru
# tuktoyaktuk ca
# esmeraldas ec
# inuvik ca
# brewster us
# colinas br
# airai pw
# barentsburg sj
# troitsko-pechorsk ru
# sanchazi cn
# barentsburg sj
# dingle ie
# hopewell us
# nipawin ca
# kruisfontein za
# polunochnoye ru
# burnie au
# mataura pf
# eldorado ar
# westport ie
# bluff nz
# bredasdorp za
# provideniya ru
# marathon ca
# chesma ru
# selfoss is
# barrow us
# new glasgow ca
# jamestown sh
# goderich sl
# busselton au
# kazalinsk kz
# klaksvik fo
# puerto ayora ec
# mataura pf
# albany au
# olafsvik is
# hobart au
# tuktoyaktuk ca
# yellowknife ca
# kavieng pg
# alexandria eg
# nome us
# cape town za
# hermanus za
# ilulissat gl
# albany au
# tashtyp ru
# shawville ca
# victoria sc
# mahebourg mu
# tautira pf
# merano it
# guerrero negro mx
# taolanaro mg
# cidreira br
# pacifica us
# iqaluit ca
# chuy uy
# takoradi gh
# tutoia br
# ushuaia ar
# chippewa falls us
# chuy uy
# cape town za
# georgetown sh
# barrow us
# belushya guba ru
# portland au
# hobart au
# mataura pf
# kapaa us
# hermanus za
# rikitea pf
# rundu na
# busselton au
# faanui pf
# fortuna us
# constitucion mx
# bethel us
# grand gaube mu
# rikitea pf
# sao sepe br
# wahran dz
# la paz mx
# isangel vu
# luderitz na
# camana pe
# hermanus za
# hermanus za
# kupang id
# porto novo cv
# cockburn harbour tc
# port blair in
# bluff nz
# jamestown sh
# lompoc us

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 593

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_488/1386398465.py in <module>
#       3
#       4 # Import the API key.
# ----> 5 from config import weather_api_key
#
# ModuleNotFoundError: No module named 'config'

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather

# %%
city_weather.status_code

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather

# %%
# Get the text of the 'Get' request.
city_weather.text

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")

# %%
print(city_url)

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']

# %%
boston_data['sys']['country']

# %%
boston_data['dt']

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")

# %%
df = pd.DataFrame(list with dictionaries)

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
