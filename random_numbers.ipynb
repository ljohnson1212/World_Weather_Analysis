# %%
# Import the random module.
import random

# %%
random.randint(-90, 90)
# Out:
# 62

# %%
random.random()
# Out:
# 0.7279068405207351

# %%
random_number = random.randint(-90, 89) + random.random()
random_number
# Out:
# -7.062095480836515

# %%
x = 1
latitudes = []
while x < 11:
    random_lat = random.randint(-90, 89) + random.random()
    latitudes.append(random_lat)
    x += 1

# %%
random.randrange(-90, 90, step=1)
# Out:
# 5

# %%
random.randrange(-90, 90, step=3)
# Out:
# -24

# %%
random.uniform(-90, 90)
# Out:
# 45.911362893854886

# %%
# Import the NumPy module.
import numpy as np

# %%
np.random.uniform(-90.000, 90.000)
# Out:
# 57.28699531559039

# %%
np.random.uniform(-90.000, 90.000, size=50)
# Out:
# array([-57.01762281, -76.81091859,  87.93665313,  81.72914959,
#        -37.26377476, -44.18817363,  -6.65702991,  39.04430271,
#         70.52054557,  57.08319822,  16.89777149,  32.01665622,
#         61.11808494, -71.71707876,  -9.51355218,  -1.18504948,
#        -19.37393539, -44.98904308, -38.39956635,  14.60757399,
#         21.30101938,  40.52168181,  80.14381206,  88.08602837,
#        -40.42455569, -35.71954331, -87.92711355, -63.13393959,
#         39.21181815, -52.73862793, -80.0232173 ,  74.92465925,
#         77.03672078, -51.90903163,  16.18578132,  -5.1201414 ,
#         47.54551631, -80.09093478, -82.2432884 , -36.02275599,
#        -80.46626113, -43.48507904, -36.4915453 , -27.19881733,
#        -16.83307581, -26.50816472,  37.59196244,  89.34088676,
#         68.5546289 ,  81.14514233])

# %%
# Import timeit.
import timeit

# %%
# %timeit np.random.uniform(-90.000, 90.000, size=1500)
# Out:
# 29 µs ± 1.2 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 1500.
# %timeit latitudes(1500)
# Out:
# 3.04 ms ± 113 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# rikitea pf
# barrow us
# tasiilaq gl
# purmerend nl
# albany au
# hovd mn
# qaanaaq gl
# atuona pf
# henties bay na
# japura br
# atuona pf
# guiratinga br
# kavieng pg
# qaanaaq gl
# caravelas br
# ahuimanu us
# faanui pf
# plouzane fr
# hobart au
# mataura pf
# kruisfontein za
# avarua ck
# albany au
# dinsor so
# dikson ru
# rancho santa margarita us
# mount gambier au
# east london za
# hilo us
# port elizabeth za
# kalomo zm
# beitbridge zw
# qaanaaq gl
# chokurdakh ru
# taolanaro mg
# bambous virieux mu
# pevek ru
# ambilobe mg
# butaritari ki
# atlantic beach us
# barrow us
# hilo us
# tadine nc
# taolanaro mg
# mao td
# mataura pf
# kapaa us
# kamenskoye ru
# hermanus za
# dunedin nz
# albany au
# busselton au
# chokurdakh ru
# vaini to
# mataura pf
# chuy uy
# fenyi cn
# ushuaia ar
# hermanus za
# vila vu
# butaritari ki
# georgetown sh
# hithadhoo mv
# kapaa us
# new norfolk au
# kodiak us
# ushuaia ar
# ostrovnoy ru
# upernavik gl
# minab ir
# sarkand kz
# karratha au
# tawkar sd
# komatsu jp
# tankara in
# goure ne
# pallavaram in
# berdigestyakh ru
# atuona pf
# yellowknife ca
# caraballeda ve
# cape town za
# cape town za
# nalut ly
# clyde river ca
# quatre cocos mu
# sentyabrskiy ru
# albany au
# albany au
# esmeraldas ec
# albany au
# port elizabeth za
# anchorage us
# manggar id
# ushuaia ar
# port lincoln au
# bredasdorp za
# antofagasta cl
# ponta do sol cv
# ushuaia ar
# jamestown sh
# bintulu my
# rikitea pf
# tasiilaq gl
# richards bay za
# tessalit ml
# busselton au
# castro cl
# saint-philippe re
# port elizabeth za
# mataura pf
# bluff nz
# san ignacio bo
# souillac mu
# bluff nz
# albany au
# tres picos mx
# tasiilaq gl
# copiapo cl
# agadez ne
# olafsvik is
# talnakh ru
# sao miguel do araguaia br
# norman wells ca
# ixtapa mx
# praya id
# punta arenas cl
# bure et
# souillac mu
# hermanus za
# albany au
# abu dhabi ae
# kieta pg
# ushuaia ar
# taolanaro mg
# skibotn no
# saskylakh ru
# barcelos br
# ponta do sol cv
# hobart au
# saint-pierre pm
# berlevag no
# rikitea pf
# qaqortoq gl
# mataura pf
# karaul ru
# geraldton au
# nouadhibou mr
# saint george bm
# mataura pf
# tiksi ru
# albany au
# pisco pe
# khatanga ru
# lavrentiya ru
# georgetown sh
# busselton au
# butaritari ki
# richards bay za
# new norfolk au
# hihifo to
# tiksi ru
# tiksi ru
# tuktoyaktuk ca
# nizhneyansk ru
# malanje ao
# avarua ck
# tasiilaq gl
# porto nacional br
# vanersborg se
# belushya guba ru
# orlik ru
# busselton au
# cape town za
# khatanga ru
# nara ml
# leningradskiy ru
# araguacu br
# ushuaia ar
# norilsk ru
# vardo no
# carnarvon au
# provideniya ru
# dikson ru
# busselton au
# matara lk
# khatanga ru
# ponta do sol cv
# gold coast au
# yellowknife ca
# eyl so
# rikitea pf
# katrineholm se
# albany au
# hermanus za
# mahebourg mu
# vaini to
# arraial do cabo br
# bredasdorp za
# iqaluit ca
# bilma ne
# puerto lopez co
# chuy uy
# busselton au
# hilo us
# mackay au
# hobart au
# yellowknife ca
# bredasdorp za
# teya ru
# rio gallegos ar
# belushya guba ru
# georgetown sh
# hobart au
# ribeira grande pt
# lishu cn
# carnarvon au
# lebowakgomo za
# puerto ayacucho ve
# numan ng
# busselton au
# port alfred za
# bluff nz
# hobart au
# amderma ru
# kapaa us
# rikitea pf
# aswan eg
# broken hill au
# dawei mm
# carnarvon au
# tasiilaq gl
# hamilton bm
# mys shmidta ru
# big rapids us
# mount gambier au
# zarubino ru
# san vicente ph
# arraial do cabo br
# ambodifototra mg
# guerrero negro mx
# mataura pf
# amderma ru
# saint-philippe re
# margate za
# kapaa us
# hermanus za
# arraial do cabo br
# san isidro ni
# avarua ck
# hermanus za
# pangody ru
# anadyr ru
# bredasdorp za
# andenes no
# mezen ru
# kaitangata nz
# labuhan id
# illoqqortoormiut gl
# gunnedah au
# hithadhoo mv
# ushuaia ar
# bambous virieux mu
# portland au
# barrow us
# cumra tr
# mys shmidta ru
# kloulklubed pw
# shache cn
# vaini to
# tsihombe mg
# port elizabeth za
# qaanaaq gl
# castro cl
# faanui pf
# rikitea pf
# busselton au
# aranos na
# san cristobal ec
# dikson ru
# rikitea pf
# ballina au
# winneba gh
# mataura pf
# kharp ru
# galle lk
# havoysund no
# atuona pf
# taksimo ru
# samusu ws
# boda cf
# hihifo to
# san patricio mx
# ilulissat gl
# saint-philippe re
# zwedru lr
# meybod ir
# new norfolk au
# mahebourg mu
# portland au
# ushuaia ar
# ribeira grande pt
# new norfolk au
# beloha mg
# half moon bay us
# hithadhoo mv
# emmett us
# ribeira grande pt
# coruripe br
# yellowknife ca
# hasaki jp
# barabinsk ru
# kaitangata nz
# marcona pe
# arraial do cabo br
# port elizabeth za
# harper lr
# vredendal za
# albany au
# mataura pf
# kaitangata nz
# touros br
# hall at
# bredasdorp za
# cidreira br
# alofi nu
# avarua ck
# busselton au
# chokurdakh ru
# villazon bo
# dixon us
# palmer us
# bluff nz
# chapais ca
# east london za
# fraga es
# tasiilaq gl
# khatanga ru
# hermanus za
# flinders au
# severo-kurilsk ru
# rikitea pf
# san patricio mx
# kruisfontein za
# avarua ck
# baherden tm
# asau tv
# punta arenas cl
# izhma ru
# bredasdorp za
# kapaa us
# dzilam gonzalez mx
# broome au
# tasiilaq gl
# riyadh sa
# dingle ie
# lampari ph
# barrow us
# severo-kurilsk ru
# georgetown sh
# georgetown sh
# ancud cl
# mar del plata ar
# ribeira grande pt
# khatanga ru
# puerto escondido mx
# sitka us
# kapaa us
# atuona pf
# castro cl
# kushmurun kz
# saint-philippe re
# iqaluit ca
# taolanaro mg
# mangan in
# hithadhoo mv
# berdigestyakh ru
# thompson ca
# tsuruoka jp
# kadykchan ru
# new norfolk au
# rikitea pf
# west bay ky
# ushuaia ar
# jaciara br
# kribi cm
# ushuaia ar
# mahebourg mu
# saskylakh ru
# progreso mx
# san juan us
# tsihombe mg
# preobrazheniye ru
# burica pa
# khatanga ru
# talcahuano cl
# sistranda no
# lichinga mz
# castro cl
# mataura pf
# rikitea pf
# bluff nz
# ushuaia ar
# cherskiy ru
# sibolga id
# ushuaia ar
# port alfred za
# palabuhanratu id
# yusva ru
# rikitea pf
# karkaralinsk kz
# atuona pf
# hermanus za
# hamilton bm
# east london za
# rikitea pf
# ushuaia ar
# coihaique cl
# navahrudak by
# kapaa us
# victoria sc
# ituni gy
# baykit ru
# mys shmidta ru
# rikitea pf
# katsuura jp
# ostrovnoy ru
# busselton au
# vrangel ru
# saskylakh ru
# bluff nz
# taolanaro mg
# ola ru
# sitka us
# butaritari ki
# vaini to
# punta arenas cl
# rikitea pf
# puerto ayora ec
# shymkent kz
# thompson ca
# clyde river ca
# saint george bm
# costa rica mx
# pisco pe
# castro cl
# kavieng pg
# krasnyy chikoy ru
# jamestown sh
# arkhangelos gr
# lethem gy
# vaini to
# punta arenas cl
# punta arenas cl
# rikitea pf
# kapaa us
# ribeira grande pt
# illoqqortoormiut gl
# jamestown sh
# torbay ca
# nalut ly
# punta arenas cl
# mana gf
# albany au
# busselton au
# isangel vu
# san ignacio pe
# the valley ai
# okha ru
# albany au
# ribeira grande pt
# new norfolk au
# barrow us
# ribeira grande pt
# punta arenas cl
# mataura pf
# avarua ck
# tecoanapa mx
# codrington ag
# yellowknife ca
# novo aripuana br
# thompson ca
# longyearbyen sj
# ushuaia ar
# georgetown sh
# mahebourg mu
# ribeira grande pt
# lolua tv
# caucaia br
# albany au

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 632

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12980/1386398465.py in <module>
#       3
#       4 # Import the API key.
# ----> 5 from config import weather_api_key
#
# ModuleNotFoundError: No module named 'config'

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12980/1257759695.py in <module>
#       1 # Starting URL for Weather Map API Call.
# ----> 2 url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#       3 print(url)
#
# NameError: name 'weather_api_key' is not defined

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather

# %%
city_weather.status_code

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
city_weather

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather

# %%
# Get the text of the 'Get' request.
city_weather.text

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Bston"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")

# %%
print(city_url)

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()

# %%
# Get the JSON data.
boston_data = city_weather.json()

# %%
boston_data['sys']

# %%
boston_data['sys']['country']

# %%
boston_data['dt']

# %%
lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12980/437264679.py in <module>
#      19
#      20     # Create endpoint URL with each city.
# ---> 21     city_url = url + "&q=" + city.replace(" ","+")
#      22
#      23     # Log the URL, record, and set numbers and the city.
#
# NameError: name 'url' is not defined

# %%
df = pd.DataFrame(list with dictionaries)

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
new_column_order = ["column2", "column4", "column1"]

# %%
df = df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
